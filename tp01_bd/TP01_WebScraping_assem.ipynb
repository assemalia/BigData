# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random
from datetime import datetime

BASE_URL = "https://www.djelfa.info/vb/forumdisplay.php?f=2&page={}"
HEADERS = {"User-Agent": "Mozilla/5.0"}
CSV_PATH = "djelfa_forum_topics.csv"


def fetch_page(page):
    """Fetch one forum page."""
    url = BASE_URL.format(page)
    resp = requests.get(url, headers=HEADERS, timeout=10)
    if resp.status_code == 200:
        return resp.text
    print(f"[!] Failed to load page {page}, code: {resp.status_code}")
    return None


def parse_forum(html, page_number):
    """Extract forum topics from HTML content."""
    soup = BeautifulSoup(html, "html.parser")
    threads = soup.select("tbody#threadbits_forum_2 tr")
    data = []

    for tr in threads:
        title_elem = tr.select_one("a[id^='thread_title_']")
        if not title_elem:
            continue

        title = title_elem.text.strip()
        link = "https://www.djelfa.info/vb/" + title_elem["href"]

        author_elem = tr.select_one("td.alt2 a[href^='member.php']")
        author = author_elem.text.strip() if author_elem else "Unknown"

        reply_elem = tr.select("td.alt1[align='center']")
        replies = reply_elem[0].text.strip() if len(reply_elem) > 0 else "0"

        view_elem = tr.select("td.alt2[align='center']")
        views = view_elem[-1].text.strip() if view_elem else "0"

        last_post_info = tr.select_one("td.alt2[title]")
        last_post_text = last_post_info.get_text(strip=True).replace("\xa0", " ") if last_post_info else "N/A"

        data.append({
             "الصفحة": page_number,
             "العنوان": title,
             "الكاتب": author,
             "الردود": replies,
             "المشاهدات": views,
             "آخر_مشاركة": last_post_text,
             "الرابط": link
        })

    return data


def main():
    print("Starting Web Scraping from Djelfa Forum...")
    start_time = datetime.now()
    all_topics = []

    for page in range(1, 200):
        print(f"\nFetching page {page}...")
        html = fetch_page(page)
        if not html:
            continue

        # Steps 1: Display HTML source code (for requrement #1)
        if page == 1:
            print("\n--- HTML Preview (first 800 characters) ---\n")
            print(html[:800])
            print("\n--- End of HTML Preview ---\n")

        # Step 2: Extract data using BeautifulSoup (for requrement #2)
        topics = parse_forum(html, page)
        print(f"Extracted {len(topics)} topics from page {page}")
        all_topics.extend(topics)

        time.sleep(random.uniform(1.0, 2.0))

    # Step 3: Save results to CSV using pandas (for requrement #3)
    if all_topics:
        df = pd.DataFrame(all_topics)
        df.to_csv(CSV_PATH, index=False, encoding="utf-8-sig")
        print(f"\n Saved {len(df)} records to '{CSV_PATH}'")
        print("\nPreview of first 10 rows:\n")
        print(df.head(10).to_string(index=False))
    else:
        print(" erreur No data found. Please check site structure or selectors.")

    print(f"\n Duration: {(datetime.now() - start_time).total_seconds():.2f} seconds")


if __name__ == "__main__":
    main()
# Out:
# Starting Web Scraping from Djelfa Forum...
#
# Fetching page 1...
#
# --- HTML Preview (first 800 characters) ---
#
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Transitional//EN" "https://www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd">
# <html xmlns="https://www.w3.org/1999/xhtml" dir="rtl" lang="ar">
# <head>
# <metaname="viewport"content="initial-scale=1, maximum-scale=1">
# <meta https-equiv="Content-Type" content="text/html; charset=windows-1256" />
# <meta name="generator" content="vBulletin 3.8.10 Release Candidate 2" />
#
# <meta name="keywords" content="الجلفة للمواضيع العامّة, منتدى الجلفة ،منتديات الجلفة، منتدى الجزائر ، منتديات الجزائر، منتدى جزائري، منتديات جزائرية،  منتدى العرب، أولاد نائل،  مدن الجزائر، المنتدى السياسي، منتدى نصرة الرسول محمد (ص)، الحضارة و المدن الإسلامية، المقاومة و المقاطعة، منتدى البرامج، الحاسوب و الأنترنت، الموبايل و الإتصالات، المصممين و تطوير المواقع، خيمة الأدب و الش
#
# --- End of HTML Preview ---
#
# Extracted 30 topics from page 1
#
# Fetching page 2...
# Extracted 30 topics from page 2
#
# Fetching page 3...
# Extracted 30 topics from page 3
#
# Fetching page 4...
# Extracted 30 topics from page 4
#
# Fetching page 5...
# Extracted 30 topics from page 5
#
# Fetching page 6...
# Extracted 30 topics from page 6
#
# Fetching page 7...
# Extracted 30 topics from page 7
#
# Fetching page 8...
# Extracted 30 topics from page 8
#
# Fetching page 9...
# Extracted 30 topics from page 9
#
# Fetching page 10...
# Extracted 30 topics from page 10
#
# Fetching page 11...
# Extracted 30 topics from page 11
#
# Fetching page 12...
# Extracted 30 topics from page 12
#
# Fetching page 13...
# Extracted 30 topics from page 13
#
# Fetching page 14...
# Extracted 30 topics from page 14
#
# Fetching page 15...
# Extracted 30 topics from page 15
#
# Fetching page 16...
# Extracted 30 topics from page 16
#
# Fetching page 17...
# Extracted 30 topics from page 17
#
# Fetching page 18...
# Extracted 30 topics from page 18
#
# Fetching page 19...
# Extracted 30 topics from page 19
#
# Fetching page 20...
# Extracted 30 topics from page 20
#
# Fetching page 21...
# Extracted 30 topics from page 21
#
# Fetching page 22...
# Extracted 30 topics from page 22
#
# Fetching page 23...
# Extracted 30 topics from page 23
#
# Fetching page 24...
# Extracted 30 topics from page 24
#
# Fetching page 25...
# Extracted 30 topics from page 25
#
# Fetching page 26...
# Extracted 30 topics from page 26
#
# Fetching page 27...
# Extracted 30 topics from page 27
#
# Fetching page 28...
# Extracted 30 topics from page 28
#
# Fetching page 29...
# Extracted 30 topics from page 29
#
# Fetching page 30...
# Extracted 30 topics from page 30
#
# Fetching page 31...
# Extracted 30 topics from page 31
#
# Fetching page 32...
# Extracted 30 topics from page 32
#
# Fetching page 33...
# Extracted 30 topics from page 33
#
# Fetching page 34...
# Extracted 30 topics from page 34
#
# Fetching page 35...
# Extracted 30 topics from page 35
#
# Fetching page 36...
# Extracted 30 topics from page 36
#
# Fetching page 37...
# Extracted 30 topics from page 37
#
# Fetching page 38...
# Extracted 30 topics from page 38
#
# Fetching page 39...
# Extracted 30 topics from page 39
#
# Fetching page 40...
# Extracted 30 topics from page 40
#
# Fetching page 41...
# Extracted 30 topics from page 41
#
# Fetching page 42...
# Extracted 30 topics from page 42
#
# Fetching page 43...
# Extracted 30 topics from page 43
#
# Fetching page 44...
# Extracted 30 topics from page 44
#
# Fetching page 45...
# Extracted 30 topics from page 45
#
# Fetching page 46...
# Extracted 30 topics from page 46
#
# Fetching page 47...
# Extracted 30 topics from page 47
#
# Fetching page 48...
# Extracted 30 topics from page 48
#
# Fetching page 49...
# Extracted 30 topics from page 49
#
# Fetching page 50...
# Extracted 30 topics from page 50
#
# Fetching page 51...
# Extracted 30 topics from page 51
#
# Fetching page 52...
# Extracted 30 topics from page 52
#
# Fetching page 53...
# Extracted 30 topics from page 53
#
# Fetching page 54...
# Extracted 30 topics from page 54
#
# Fetching page 55...
# Extracted 30 topics from page 55
#
# Fetching page 56...
# Extracted 30 topics from page 56
#
# Fetching page 57...
# Extracted 30 topics from page 57
#
# Fetching page 58...
# Extracted 30 topics from page 58
#
# Fetching page 59...
# Extracted 30 topics from page 59
#
# Fetching page 60...
# Extracted 30 topics from page 60
#
# Fetching page 61...
# Extracted 30 topics from page 61
#
# Fetching page 62...
# Extracted 30 topics from page 62
#
# Fetching page 63...
# Extracted 30 topics from page 63
#
# Fetching page 64...
# Extracted 30 topics from page 64
#
# Fetching page 65...
# Extracted 30 topics from page 65
#
# Fetching page 66...
# Extracted 30 topics from page 66
#
# Fetching page 67...
# Extracted 30 topics from page 67
#
# Fetching page 68...
# Extracted 30 topics from page 68
#
# Fetching page 69...
# Extracted 30 topics from page 69
#
# Fetching page 70...
# Extracted 30 topics from page 70
#
# Fetching page 71...
# Extracted 30 topics from page 71
#
# Fetching page 72...
# Extracted 30 topics from page 72
#
# Fetching page 73...
# Extracted 30 topics from page 73
#
# Fetching page 74...
# Extracted 30 topics from page 74
#
# Fetching page 75...
# Extracted 30 topics from page 75
#
# Fetching page 76...
# Extracted 30 topics from page 76
#
# Fetching page 77...
# Extracted 30 topics from page 77
#
# Fetching page 78...
# Extracted 30 topics from page 78
#
# Fetching page 79...
# Extracted 30 topics from page 79
#
# Fetching page 80...
# Extracted 30 topics from page 80
#
# Fetching page 81...
# Extracted 30 topics from page 81
#
# Fetching page 82...
# Extracted 30 topics from page 82
#
# Fetching page 83...
# Extracted 30 topics from page 83
#
# Fetching page 84...
# Extracted 30 topics from page 84
#
# Fetching page 85...
# Extracted 30 topics from page 85
#
# Fetching page 86...
# Extracted 30 topics from page 86
#
# Fetching page 87...
# Extracted 30 topics from page 87
#
# Fetching page 88...
# Extracted 30 topics from page 88
#
# Fetching page 89...
# Extracted 30 topics from page 89
#
# Fetching page 90...
# Extracted 30 topics from page 90
#
# Fetching page 91...
# Extracted 30 topics from page 91
#
# Fetching page 92...
# Extracted 30 topics from page 92
#
# Fetching page 93...
# Extracted 30 topics from page 93
#
# Fetching page 94...
# Extracted 30 topics from page 94
#
# Fetching page 95...
# Extracted 30 topics from page 95
#
# Fetching page 96...
# Extracted 30 topics from page 96
#
# Fetching page 97...
# Extracted 30 topics from page 97
#
# Fetching page 98...
# Extracted 30 topics from page 98
#
# Fetching page 99...
# Extracted 30 topics from page 99
#
# Fetching page 100...
# Extracted 30 topics from page 100
#
# Fetching page 101...
# Extracted 30 topics from page 101
#
# Fetching page 102...
# Extracted 30 topics from page 102
#
# Fetching page 103...
# Extracted 30 topics from page 103
#
# Fetching page 104...
# Extracted 30 topics from page 104
#
# Fetching page 105...
# Extracted 30 topics from page 105
#
# Fetching page 106...
# Extracted 30 topics from page 106
#
# Fetching page 107...
# Extracted 30 topics from page 107
#
# Fetching page 108...
# Extracted 30 topics from page 108
#
# Fetching page 109...
# Extracted 30 topics from page 109
#
# Fetching page 110...
# Extracted 30 topics from page 110
#
# Fetching page 111...
# Extracted 30 topics from page 111
#
# Fetching page 112...
# Extracted 30 topics from page 112
#
# Fetching page 113...
# Extracted 30 topics from page 113
#
# Fetching page 114...
# Extracted 30 topics from page 114
#
# Fetching page 115...
# Extracted 30 topics from page 115
#
# Fetching page 116...
# Extracted 30 topics from page 116
#
# Fetching page 117...
# Extracted 30 topics from page 117
#
# Fetching page 118...
# Extracted 30 topics from page 118
#
# Fetching page 119...
# Extracted 30 topics from page 119
#
# Fetching page 120...
# Extracted 30 topics from page 120
#
# Fetching page 121...
# Extracted 30 topics from page 121
#
# Fetching page 122...
# Extracted 30 topics from page 122
#
# Fetching page 123...
# Extracted 30 topics from page 123
#
# Fetching page 124...
# Extracted 30 topics from page 124
#
# Fetching page 125...
# Extracted 30 topics from page 125
#
# Fetching page 126...
# Extracted 30 topics from page 126
#
# Fetching page 127...
# Extracted 30 topics from page 127
#
# Fetching page 128...
# Extracted 30 topics from page 128
#
# Fetching page 129...
# Extracted 30 topics from page 129
#
# Fetching page 130...
# Extracted 30 topics from page 130
#
# Fetching page 131...
# Extracted 30 topics from page 131
#
# Fetching page 132...
# Extracted 30 topics from page 132
#
# Fetching page 133...
# Extracted 30 topics from page 133
#
# Fetching page 134...
# Extracted 30 topics from page 134
#
# Fetching page 135...
# Extracted 30 topics from page 135
#
# Fetching page 136...
# Extracted 30 topics from page 136
#
# Fetching page 137...
# Extracted 30 topics from page 137
#
# Fetching page 138...
# Extracted 30 topics from page 138
#
# Fetching page 139...
# Extracted 30 topics from page 139
#
# Fetching page 140...
# Extracted 30 topics from page 140
#
# Fetching page 141...
# Extracted 30 topics from page 141
#
# Fetching page 142...
# Extracted 30 topics from page 142
#
# Fetching page 143...
# Extracted 30 topics from page 143
#
# Fetching page 144...
# Extracted 30 topics from page 144
#
# Fetching page 145...
# Extracted 30 topics from page 145
#
# Fetching page 146...
# Extracted 30 topics from page 146
#
# Fetching page 147...
# Extracted 30 topics from page 147
#
# Fetching page 148...
# Extracted 30 topics from page 148
#
# Fetching page 149...
# Extracted 30 topics from page 149
#
# Fetching page 150...
# Extracted 30 topics from page 150
#
# Fetching page 151...
# Extracted 30 topics from page 151
#
# Fetching page 152...
# Extracted 30 topics from page 152
#
# Fetching page 153...
# Extracted 30 topics from page 153
#
# Fetching page 154...
# Extracted 30 topics from page 154
#
# Fetching page 155...
# Extracted 30 topics from page 155
#
# Fetching page 156...
# Extracted 30 topics from page 156
#
# Fetching page 157...
# Extracted 30 topics from page 157
#
# Fetching page 158...
# Extracted 30 topics from page 158
#
# Fetching page 159...
# Extracted 30 topics from page 159
#
# Fetching page 160...
# Extracted 30 topics from page 160
#
# Fetching page 161...
# Extracted 30 topics from page 161
#
# Fetching page 162...
# Extracted 30 topics from page 162
#
# Fetching page 163...
# Extracted 30 topics from page 163
#
# Fetching page 164...
# Extracted 30 topics from page 164
#
# Fetching page 165...
# Extracted 30 topics from page 165
#
# Fetching page 166...
# Extracted 30 topics from page 166
#
# Fetching page 167...
# Extracted 30 topics from page 167
#
# Fetching page 168...
# Extracted 30 topics from page 168
#
# Fetching page 169...
# Extracted 30 topics from page 169
#
# Fetching page 170...
# Extracted 30 topics from page 170
#
# Fetching page 171...
# Extracted 30 topics from page 171
#
# Fetching page 172...
# Extracted 30 topics from page 172
#
# Fetching page 173...
# Extracted 30 topics from page 173
#
# Fetching page 174...
# Extracted 30 topics from page 174
#
# Fetching page 175...
# Extracted 30 topics from page 175
#
# Fetching page 176...
# Extracted 30 topics from page 176
#
# Fetching page 177...
# Extracted 30 topics from page 177
#
# Fetching page 178...
# Extracted 30 topics from page 178
#
# Fetching page 179...
# Extracted 30 topics from page 179
#
# Fetching page 180...
# Extracted 30 topics from page 180
#
# Fetching page 181...
# Extracted 30 topics from page 181
#
# Fetching page 182...
# Extracted 30 topics from page 182
#
# Fetching page 183...
# Extracted 30 topics from page 183
#
# Fetching page 184...
# Extracted 30 topics from page 184
#
# Fetching page 185...
# Extracted 30 topics from page 185
#
# Fetching page 186...
# Extracted 30 topics from page 186
#
# Fetching page 187...
# Extracted 30 topics from page 187
#
# Fetching page 188...
# Extracted 30 topics from page 188
#
# Fetching page 189...
# Extracted 30 topics from page 189
#
# Fetching page 190...
# Extracted 30 topics from page 190
#
# Fetching page 191...
# Extracted 30 topics from page 191
#
# Fetching page 192...
# Extracted 30 topics from page 192
#
# Fetching page 193...
# Extracted 30 topics from page 193
#
# Fetching page 194...
# Extracted 30 topics from page 194
#
# Fetching page 195...
# Extracted 30 topics from page 195
#
# Fetching page 196...
# Extracted 30 topics from page 196
#
# Fetching page 197...
# Extracted 30 topics from page 197
#
# Fetching page 198...
# Extracted 30 topics from page 198
#
# Fetching page 199...
# Extracted 30 topics from page 199
#
#  Saved 5970 records to 'djelfa_forum_topics.csv'
#
# Preview of first 10 rows:
#
#  الصفحة                                                     العنوان         الكاتب الردود المشاهدات                 آخر_مشاركة                                                                                 الرابط
#       1                              وحين إلتقيتك عاد قلبي .. نابضا            أثر      0        40            يوم أمس22:15أثر https://www.djelfa.info/vb/showthread.php?s=575e00653a92ed354d40ed42f51aa9e6&t=2339982
#       1                                     السوداء التي أحبها قلبي            أثر     20       282            يوم أمس21:26أثر https://www.djelfa.info/vb/showthread.php?s=575e00653a92ed354d40ed42f51aa9e6&t=2339975
#       1             متى يستدرك أمر الراية الوطنية، في لونها الأخضر؟ Mohand_Zekrini      3       236 يوم أمس13:13Mohand_Zekrini https://www.djelfa.info/vb/showthread.php?s=575e00653a92ed354d40ed42f51aa9e6&t=2339927
#       1                               هل لك من إسمك نصيب يا ترى  ؟؟            أثر     15       271         يوم أمس12:50Noetic https://www.djelfa.info/vb/showthread.php?s=575e00653a92ed354d40ed42f51aa9e6&t=2339966
#       1                              **طريق نحو الفوضى والانحطاط**.        السجنجل      3       128            يوم أمس12:43أثر https://www.djelfa.info/vb/showthread.php?s=575e00653a92ed354d40ed42f51aa9e6&t=2339974
#       1                             لم يكن قلمي بالمستوى المطلوب ..           حمزة      2        91            يوم أمس06:37أثر https://www.djelfa.info/vb/showthread.php?s=575e00653a92ed354d40ed42f51aa9e6&t=2339977
#       1                                   الحاجة إلى استنشاق السكون         Noetic      0        64      2025-10-1417:39Noetic https://www.djelfa.info/vb/showthread.php?s=575e00653a92ed354d40ed42f51aa9e6&t=2339976
#       1                                سجل حضورك من خلال سنة تسجيلك           حمزة     10       372         2025-10-1414:51أثر https://www.djelfa.info/vb/showthread.php?s=575e00653a92ed354d40ed42f51aa9e6&t=2339946
#       1                                              احذر من الكلام     علي هزايمه      1       219    2025-10-1412:53adomanim https://www.djelfa.info/vb/showthread.php?s=575e00653a92ed354d40ed42f51aa9e6&t=2339580
#       1 الإعلان عن نتائج مسابقة أفضل تحليل لمواضيع القضايا الهامة ✨         Noetic      9       458    2025-10-1412:52adomanim https://www.djelfa.info/vb/showthread.php?s=575e00653a92ed354d40ed42f51aa9e6&t=2339430
#
#  Duration: 533.56 seconds
